# %% [markdown]
# ##Ploting Series

# %%
#matplotlib library is used for plotting

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd

# %%
temperatures =[4.4, 16,100, 68, 56,0.06777,36,9.8999,2000]
s= pd.Series(temperatures, name="Temp")
s.plot()
plt.show()
