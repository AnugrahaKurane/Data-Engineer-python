# %%
import pandas

# %%
print(pandas.__version__)
# Out:
# 2.0.3

# %%
csv_file = pandas.read_csv('C:/Users/RAMESHKA/Desktop/Datasets/Datasets/feature_engineering.csv')
csv_file  
#by default index is generated
# Out:
#     UserId
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
# ..     ...
# 77      78
# 78      79
# 79      80
# 80      81
# 81      82
#
# [82 rows x 1 columns]

# %%
type(csv_file)
# Out:
# pandas.core.frame.DataFrame

# %%
## DATA SELECTION

# %%
product_df = pandas.read_csv('C:/Users/RAMESHKA/Desktop/Datasets/Datasets/product_data.csv')
product_df
# Out:
#      ProductID ProductName   Cost ShippingLocation SellerName
# 0            1       LEDTV  32990            Delhi    ABC Pvt
# 1            2     Printer   5990            Delhi    ABC Pvt
# 2            3    Split AC  32050             Pune    XY Corp
# 3            4   Microwave  12670           Mumbai    PQ Corp

# %%
type(product_df)
# Out:
# pandas.core.frame.DataFrame

# %%
# To retrive the data from specific column
product_df['ProductName']
# Out:
# 0        LEDTV
# 1      Printer
# 2     Split AC
# 3    Microwave
# Name: ProductName, dtype: object

# %%
# Select multiple column
listOfColumn = ['ProductName','Cost','SellerName'] #1
product_df[listOfColumn]
# Out:
#   ProductName   Cost SellerName
# 0       LEDTV  32990    ABC Pvt
# 1     Printer   5990    ABC Pvt
# 2    Split AC  32050    XY Corp
# 3   Microwave  12670    PQ Corp

# %%
product_df[["Cost","ShippingLocation"]] #2 these are 2 ways of retriving data from multiple column
# Out:
#     Cost ShippingLocation
# 0  32990            Delhi
# 1   5990            Delhi
# 2  32050             Pune
# 3  12670           Mumbai

# %%
#For selecting rows with index 2
index= 2
product_df.loc[index] # loc[] function is must for retriving data index wise
# Out:
#   ProductID                3
# ProductName         Split AC
# Cost                   32050
# ShippingLocation        Pune
# SellerName           XY Corp
# Name: 2, dtype: object

# %%
#for selecting rows with index less than 2
index= 2
product_df.loc[:index]
# Out:
#      ProductID ProductName   Cost ShippingLocation SellerName
# 0            1       LEDTV  32990            Delhi    ABC Pvt
# 1            2     Printer   5990            Delhi    ABC Pvt
# 2            3    Split AC  32050             Pune    XY Corp

# %%
#Select top 2 rows
row =2
product_df.iloc[:row] #iloc[] -> Index specified loc
# Out:
#      ProductID ProductName   Cost ShippingLocation SellerName
# 0            1       LEDTV  32990            Delhi    ABC Pvt
# 1            2     Printer   5990            Delhi    ABC Pvt

# %%
#bottom 2 rows selection
row =2
product_df.iloc[-row] #1
# Out:
#   ProductID               2
# ProductName         Printer
# Cost                   5990
# ShippingLocation      Delhi
# SellerName          ABC Pvt
# Name: 1, dtype: object

# %%
product_df.iloc[-3] #2 another way of selecting botton 2 rows
# Out:
#   ProductID               2
# ProductName         Printer
# Cost                   5990
# ShippingLocation      Delhi
# SellerName          ABC Pvt
# Name: 1, dtype: object

# %%
#select all rows with 3 columns
product_df.iloc[:,1:4]
# Out:
#   ProductName   Cost ShippingLocation
# 0       LEDTV  32990            Delhi
# 1     Printer   5990            Delhi
# 2    Split AC  32050             Pune
# 3   Microwave  12670           Mumbai

# %%
product_df.iloc[1:4]
# Out:
#      ProductID ProductName   Cost ShippingLocation SellerName
# 1            2     Printer   5990            Delhi    ABC Pvt
# 2            3    Split AC  32050             Pune    XY Corp
# 3            4   Microwave  12670           Mumbai    PQ Corp

# %%
product_df.iloc[0:4]
# Out:
#      ProductID ProductName   Cost ShippingLocation SellerName
# 0            1       LEDTV  32990            Delhi    ABC Pvt
# 1            2     Printer   5990            Delhi    ABC Pvt
# 2            3    Split AC  32050             Pune    XY Corp
# 3            4   Microwave  12670           Mumbai    PQ Corp

# %%
product_df.iloc[:,0:7]
# Out:
#      ProductID ProductName   Cost ShippingLocation SellerName
# 0            1       LEDTV  32990            Delhi    ABC Pvt
# 1            2     Printer   5990            Delhi    ABC Pvt
# 2            3    Split AC  32050             Pune    XY Corp
# 3            4   Microwave  12670           Mumbai    PQ Corp

# %%
product_df[product_df['Cost']>=30000]
# Out:
#      ProductID ProductName   Cost ShippingLocation SellerName
# 0            1       LEDTV  32990            Delhi    ABC Pvt
# 2            3    Split AC  32050             Pune    XY Corp

# %%
product_df[(product_df['Cost']<=35000) & (product_df['Cost']>=10000)]
# Out:
#      ProductID ProductName   Cost ShippingLocation SellerName
# 0            1       LEDTV  32990            Delhi    ABC Pvt
# 2            3    Split AC  32050             Pune    XY Corp
# 3            4   Microwave  12670           Mumbai    PQ Corp

# %%
product_df[(product_df['Cost']<=35000) | (product_df['Cost']>=10000)]
# Out:
#      ProductID ProductName   Cost ShippingLocation SellerName
# 0            1       LEDTV  32990            Delhi    ABC Pvt
# 1            2     Printer   5990            Delhi    ABC Pvt
# 2            3    Split AC  32050             Pune    XY Corp
# 3            4   Microwave  12670           Mumbai    PQ Corp

# %%
# Renaming the columns
#product_df = product_df.rename(columns={'Cost':'Price','ShippingLoaction':'Destibation'})
product_df = product_df.rename(columns={'Cost':'Price','Destibation':'Destination'})
product_df
# Out:
#      ProductID ProductName  Price Destination SellerName
# 0            1       LEDTV  32990       Delhi    ABC Pvt
# 1            2     Printer   5990       Delhi    ABC Pvt
# 2            3    Split AC  32050        Pune    XY Corp
# 3            4   Microwave  12670      Mumbai    PQ Corp

# %%
#Add new column
#SO new column must be entered with some value
product_df['NumberOfProducts']=1
product_df
# Out:
#      ProductID ProductName  Price Destination SellerName  NumberOfProducts
# 0            1       LEDTV  32990       Delhi    ABC Pvt                 1
# 1            2     Printer   5990       Delhi    ABC Pvt                 1
# 2            3    Split AC  32050        Pune    XY Corp                 1
# 3            4   Microwave  12670      Mumbai    PQ Corp                 1

# %%
product_df.isnull() # checking for null value
# Out:
#      ProductID  ProductName  Price  Destination  SellerName  NumberOfProducts
# 0        False        False  False        False       False             False
# 1        False        False  False        False       False             False
# 2        False        False  False        False       False             False
# 3        False        False  False        False       False             False

# %%
titanic=pandas.read_csv('C:/Users/RAMESHKA/Desktop/Datasets/Datasets/titanic_data.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
##Drop null value

#Drop all rows having any null value
titanic.dropna(axis=0) #dropna() function is used
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Drop all columns having any null value
titanic.dropna(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
#Drop all roes having less than k null value
titanic.dropna(axis=0,thresh=5)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Drop all columns having all null value
titanic.dropna(axis=0,how='all')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#replace all occurence of 0 with 1

# %%
titanic.replace(0,1)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         1       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         1       3
# ..           ...       ...     ...
# 886          887         1       2
# 887          888         1       1
# 888          889         1       3
# 889          890         1       1
# 890          891         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
product_df.replace(0,1)
# Out:
#      ProductID ProductName  Price Destination SellerName  NumberOfProducts
# 0            1       LEDTV  32990       Delhi    ABC Pvt                 1
# 1            2     Printer   5990       Delhi    ABC Pvt                 1
# 2            3    Split AC  32050        Pune    XY Corp                 1
# 3            4   Microwave  12670      Mumbai    PQ Corp                 1

# %%
product_df.replace(1,2)
# Out:
#      ProductID ProductName  Price Destination SellerName  NumberOfProducts
# 0            2       LEDTV  32990       Delhi    ABC Pvt                 2
# 1            2     Printer   5990       Delhi    ABC Pvt                 2
# 2            3    Split AC  32050        Pune    XY Corp                 2
# 3            4   Microwave  12670      Mumbai    PQ Corp                 2

# %%
#Replace all NA vales
#fill all NA values
titanic.fillna(0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic['Cabin'].fillna(22)
# Out:
# 0        22
# 1       C85
# 2        22
# 3      C123
# 4        22
#        ...
# 886      22
# 887     B42
# 888      22
# 889    C148
# 890      22
# Name: Cabin, Length: 891, dtype: object

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
##Grouping the data

#Grouping on data by sellername
product_df.groupby('SellerName') #groupby class

# %%
#we can also group the data based on multiple columns
score = product_df.groupby(['SellerName','Price'])
score

# %%
#Aplly statistics for grouping
product_df['Price'].groupby(product_df['SellerName']).mean()
# Out:
# SellerName
# ABC Pvt    19490.0
# PQ Corp    12670.0
# XY Corp    32050.0
# Name: Price, dtype: float64

# %%
product_df['Price'].groupby(product_df['SellerName']).count()
# Out:
# SellerName
# ABC Pvt    2
# PQ Corp    1
# XY Corp    1
# Name: Price, dtype: int64

# %%
titanic['Fare'].groupby(titanic['Sex']).mean()
# Out:
# Sex
# female    44.479818
# male      25.523893
# Name: Fare, dtype: float64

# %%
titanic['Fare'].groupby(titanic['Sex']).count()
# Out:
# Sex
# female    314
# male      577
# Name: Fare, dtype: int64

# %%
titanic['Sex'].groupby(titanic['Survived']).count()
# Out:
# Survived
# 0    549
# 1    342
# Name: Sex, dtype: int64

# %%
# product_df[(product_df['Cost']<=35000) & (product_df['Cost']>=10000)]

# %%
titanic['Survived'].groupby(titanic['Sex']).sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
titanic['Fare'].groupby(titanic['Sex']).sum()
# Out:
# Sex
# female    13966.6628
# male      14727.2865
# Name: Fare, dtype: float64

# %%
titanic['Fare'].groupby(titanic['Sex']).min()
# Out:
# Sex
# female    6.75
# male      0.00
# Name: Fare, dtype: float64

# %%
titanic['Fare'].groupby(titanic['Sex']).mean() #mean() is average value
# Out:
# Sex
# female    44.479818
# male      25.523893
# Name: Fare, dtype: float64

# %%
titanic['Fare'].groupby(titanic['Sex']).median()
# Out:
# Sex
# female    23.0
# male      10.5
# Name: Fare, dtype: float64

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Sort values by cost
titanic.sort_values(by='Fare') # it gives the order ascending
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 271          272         1       3        Tornquist, Mr. William Henry
# 597          598         0       3                 Johnson, Mr. Alfred
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 277          278         0       2         Parkes, Mr. Francis "Frank"
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
#If we want to sort values in descending order
titanic.sort_values(by='Fare',ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
# #Sort values for multiple column
titanic.sort_values(by=['Fare','Age'])
#here Fare is given first preference for sorting then age is preferred, as Fare is mentioned first here
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# 271          272         1       3        Tornquist, Mr. William Henry
# 179          180         0       3                 Leonard, Mr. Lionel
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 806          807         0       1              Andrews, Mr. Thomas Jr
# ..           ...       ...     ...                                 ...
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 438          439         0       1                   Fortune, Mr. Mark
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...

# %%
titanic.sort_values(by=['Age','Fare'])
#here Age is given first preference for sorting then Fare is preferred, as Age is mentioned first here
# Out:
#      PassengerId  Survived  Pclass  \
# 803          804         1       3
# 755          756         1       2
# 469          470         1       3
# 644          645         1       3
# 831          832         1       2
# ..           ...       ...     ...
# 306          307         1       1
# 334          335         1       1
# 31            32         1       1
# 527          528         0       1
# 557          558         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 803                    Thomas, Master. Assad Alexander    male  0.42      0
# 755                          Hamalainen, Master. Viljo    male  0.67      1
# 469                      Baclini, Miss. Helene Barbara  female  0.75      2
# 644                             Baclini, Miss. Eugenie  female  0.75      2
# 831                    Richards, Master. George Sibley    male  0.83      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Declare lambda function
st=lambda x:x.lower()

#Apply on any column of datafame
titanic['Fare'].apply(st)

# %% [markdown]
# ## Pandas - Series Objects

# %%
#init from python dict

# %%
weights = {"aluce":68,"bob":89,"darwin":70}
s=pandas.Series(weights) #we can use pd.series(weights)......To use like this import pandas as pd
print(s)
# Out:
# aluce     68
# bob       89
# darwin    70
# dtype: int64

# %%
#Creating a dataframe - Pass a dictionary of series objects
# Here will use dataFrame function

# %%
people= {"Weights":pandas.Series([83,12,24],index=["Alice","Bob","Charlie"]),
        "BirthYear":pandas.Series([2000,1990,1945],index=["Alice","Bob","Charlie"],name="year"),
         "Children":pandas.Series([0,2],index=["Alice","Bob"]),
         "hobby":pandas.Series(["Dancing","Singing"],index=["Alice","Bob"])}
print(people)
# Out:
# {'Weights': Alice      83
# Bob        12
# Charlie    24
# dtype: int64, 'BirthYear': Alice      2000
# Bob        1990
# Charlie    1945
# Name: year, dtype: int64, 'Children': Alice    0
# Bob      2
# dtype: int64, 'hobby': Alice    Dancing
# Bob      Singing
# dtype: object}

# %%
p=pandas.DataFrame(people)  # DataFrame() function used from framing/strictring the data
print(p)
# Out:
#          Weights  BirthYear  Children    hobby
# Alice         83       2000       0.0  Dancing
# Bob           12       1990       2.0  Singing
# Charlie       24       1945       NaN      NaN
